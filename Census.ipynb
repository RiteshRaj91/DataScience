# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r'C:\Users\HP\Desktop\Dataset\census-income_.csv')
data.head(32)
# Out:
#     age          workclass   fnlwgt      education   education-num  \
# 0    39          State-gov    77516      Bachelors              13
# 1    50   Self-emp-not-inc    83311      Bachelors              13
# 2    38            Private   215646        HS-grad               9
# 3    53            Private   234721           11th               7
# 4    28            Private   338409      Bachelors              13
# 5    37            Private   284582        Masters              14
# 6    49            Private   160187            9th               5
# 7    52   Self-emp-not-inc   209642        HS-grad               9
# 8    31            Private    45781        Masters              14
# 9    42            Private   159449      Bachelors              13
# 10   37            Private   280464   Some-college              10
# 11   30          State-gov   141297      Bachelors              13
# 12   23            Private   122272      Bachelors              13
# ...

# %%
data[' education-num'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#       dtype=int64)

# %%
data=pd.read_csv(r'C:\Users\HP\Desktop\Dataset\census-income_.csv',na_values='?',skipinitialspace=True)
data.head(32)
# Out:
#     age         workclass  fnlwgt     education  education-num  \
# 0    39         State-gov   77516     Bachelors             13
# 1    50  Self-emp-not-inc   83311     Bachelors             13
# 2    38           Private  215646       HS-grad              9
# 3    53           Private  234721          11th              7
# 4    28           Private  338409     Bachelors             13
# 5    37           Private  284582       Masters             14
# 6    49           Private  160187           9th              5
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 8    31           Private   45781       Masters             14
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
# 12   23           Private  122272     Bachelors             13
# 13   32           Private  205019    Assoc-acdm             12
# ...

# %%
data.columns=data.columns.str.replace(' ','_')
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Unnamed:_14'],
#       dtype='object')

# %%
data['education-num'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#       dtype=int64)

# %%
data['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', nan, 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
data.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# Unnamed:_14          0
# dtype: int64

# %%
data.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education-num   32561.0      10.080679       2.572720      1.0       9.0
# capital-gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital-loss    32561.0      87.303830     402.960219      0.0       0.0
# hours-per-week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %%
census_ed=data[['education']]
census_ed.head()
# Out:
#    education
# 0  Bachelors
# 1  Bachelors
# 2    HS-grad
# 3       11th
# 4  Bachelors

# %%
census_ed=data['education']
census_ed.head()
# Out:
# 0    Bachelors
# 1    Bachelors
# 2      HS-grad
# 3         11th
# 4    Bachelors
# Name: education, dtype: object

# %%
census_seq=data.iloc[:,0:8]
census_seq.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship
# 0       Never-married       Adm-clerical  Not-in-family
# 1  Married-civ-spouse    Exec-managerial        Husband
# 2            Divorced  Handlers-cleaners  Not-in-family
# 3  Married-civ-spouse  Handlers-cleaners        Husband
# 4  Married-civ-spouse     Prof-specialty           Wife

# %%
census_col=data.iloc[:,[5,8,11]]
census_col.head()
# Out:
#        marital-status   race  capital-loss
# 0       Never-married  White             0
# 1  Married-civ-spouse  White             0
# 2            Divorced  White             0
# 3  Married-civ-spouse  Black             0
# 4  Married-civ-spouse  Black             0

# %%
# Extract all the male employees who work in state-gov and store it in “male_gov”
male_gov=data[(data['workclass']=='State-gov') & (data['sex']=='Male')]
male_gov
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 0       39  State-gov   77516     Bachelors             13
# 11      30  State-gov  141297     Bachelors             13
# 34      22  State-gov  311512  Some-college             10
# 48      41  State-gov  101603     Assoc-voc             11
# 123     29  State-gov  267989     Bachelors             13
# ...    ...        ...     ...           ...            ...
# 32163   36  State-gov  135874     Bachelors             13
# 32241   45  State-gov  231013     Bachelors             13
# 32321   54  State-gov  138852       HS-grad              9
# 32324   42  State-gov  138162  Some-college             10
# 32360   58  State-gov  200316       HS-grad              9
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# 11     Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
# ...

# %%
census=data[(data['age']==39)]
census_us=census[(census['education']=='Bachelors') | (census['native-country']=='United-States')]
census_us
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 28      39           Private  367260       HS-grad              9
# 129     39           Private  365739  Some-college             10
# 166     39       Federal-gov  235485    Assoc-acdm             12
# 320     39  Self-emp-not-inc  174308       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32146   39           Private  117381  Some-college             10
# 32260   39       Federal-gov  232036  Some-college             10
# 32428   39       Federal-gov  110622     Bachelors             13
# 32468   39  Self-emp-not-inc  193689       HS-grad              9
# 32545   39         Local-gov  111499    Assoc-acdm             12
#
#            marital-status        occupation   relationship  \
# 0           Never-married      Adm-clerical  Not-in-family
# ...

# %%
#sample()helps us o get random rows
census_200=data.sample(200)

# %%
census_200
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 25448   29           Private  112403  Some-college             10
# 1333    57           Private  265099   Prof-school             15
# 31465   48  Self-emp-not-inc  191389  Some-college             10
# 11620   67  Self-emp-not-inc  345236     Bachelors             13
# 22367   44           Private  367749     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 18398   28      Self-emp-inc  146042       HS-grad              9
# 31439   17           Private  375657          11th              7
# 19357   26           Private  322547     Bachelors             13
# 871     24           Private  121313  Some-college             10
# 20610   90           Private  206667       Masters             14
#
#            marital-status         occupation   relationship   race     sex  \
# 25448       Never-married  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
data[['workclass']].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# dtype: int64

# %%
data.groupby(['workclass'])['capital-gain'].mean()
# Out:
# workclass
# Federal-gov          833.232292
# Local-gov            880.202580
# Never-worked           0.000000
# Private              889.217792
# Self-emp-inc        4875.693548
# Self-emp-not-inc    1886.061787
# State-gov            701.699538
# Without-pay          487.857143
# Name: capital-gain, dtype: float64

# %%
data['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
income=data['Unnamed:_14']
data['income']=income
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country Unnamed:_14  \
# 0          2174             0              40  United-States       <=50K
# ...

# %%
data['income'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
data=pd.DataFrame(data)
data.drop('Unnamed:_14',axis=1,inplace=True)
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
male_50=data[(data['sex']=='Male') & (data['income']=='>50K')]
female_50=data[(data['sex']=='Female') & (data['income']=='>50K')]

# %%
male_50
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# ...    ...               ...     ...           ...            ...
# 32532   34           Private  204461     Doctorate             16
# 32533   54           Private  337992     Bachelors             13
# 32539   71               NaN  287372     Doctorate             16
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
#
#            marital-status         occupation relationship                race  \
# 7      Married-civ-spouse    Exec-managerial      Husband               White
# ...

# %%
female_50
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 8       31           Private   45781      Masters             14
# 19      43  Self-emp-not-inc  292175      Masters             14
# 52      47           Private   51835  Prof-school             15
# 67      53           Private  169846      HS-grad              9
# 84      44           Private  343591      HS-grad              9
# ...    ...               ...     ...          ...            ...
# 32530   35               NaN  320084    Bachelors             13
# 32536   34           Private  160216    Bachelors             13
# 32538   38           Private  139180    Bachelors             13
# 32545   39         Local-gov  111499   Assoc-acdm             12
# 32560   52      Self-emp-inc  287927      HS-grad              9
#
#            marital-status       occupation   relationship   race     sex  \
# 8           Never-married   Prof-specialty  Not-in-family  White  Female
# ...

# %%
data['marital-status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
total=len(data['marital-status'])
married=14976+418+23
precen_mar=(married/total)*100
precen_mar
# Out:
# 47.34805442093302

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
lr=LinearRegression()

# %%
x=data[['education-num']]

# %%
y=data['hours-per-week']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=0)

# %%
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([40.41923162, 42.47912517, 41.79249399, ..., 42.47912517,
#        40.41923162, 39.73260043])

# %%
y_test
# Out:
# 22278    44
# 8950     40
# 7838     40
# 16505    40
# 19140    76
#          ..
# 21949    35
# 26405    45
# 23236    40
# 26823    40
# 20721    40
# Name: hours-per-week, Length: 9769, dtype: int64

# %%
error=y_test-y_pred
error
# Out:
# 22278     3.580768
# 8950     -2.479125
# 7838     -1.792494
# 16505     4.387187
# 19140    37.640662
#            ...
# 21949    -7.479125
# 26405     1.147612
# 23236    -2.479125
# 26823    -0.419232
# 20721     0.267400
# Name: hours-per-week, Length: 9769, dtype: float64

# %%
print('mean_squared error :',mean_squared_error(y_test,y_pred))
# Out:
# mean_squared error : 151.97722636288782

# %%
print('root-mean_squared error :',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# root-mean_squared error : 12.327904378396509

# %%
#logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lo=LogisticRegression()

# %%
data.shape
# Out:
# (32561, 15)

# %%
x=data['occupation']
x=pd.DataFrame(x)
x
# Out:
#               occupation
# 0           Adm-clerical
# 1        Exec-managerial
# 2      Handlers-cleaners
# 3      Handlers-cleaners
# 4         Prof-specialty
# ...                  ...
# 32556       Tech-support
# 32557  Machine-op-inspct
# 32558       Adm-clerical
# 32559       Adm-clerical
# 32560    Exec-managerial
#
# [32561 rows x 1 columns]

# %%
y=data['income'].replace('<=50K',0).replace('>50K',1)
y.value_counts()
# Out:
# 0    24720
# 1     7841
# Name: income, dtype: int64

# %%
len(y)
# Out:
# 32561

# %%
L=LabelEncoder()

# %%
x=L.fit_transform(x)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
x=pd.DataFrame(x)
x
# Out:
#         0
# 0       0
# 1       3
# 2       5
# 3       5
# 4       9
# ...    ..
# 32556  12
# 32557   6
# 32558   0
# 32559   0
# 32560   3
#
# [32561 rows x 1 columns]

# %%
x.value_counts()
# Out:
# 9     4140
# 2     4099
# 3     4066
# 0     3770
# 11    3650
# 7     3295
# 6     2002
# 14    1843
# 13    1597
# 5     1370
# 4      994
# 12     928
# 10     649
# 8      149
# 1        9
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.35,random_state=0)

# %%
lo=LogisticRegression()
lo.fit(x_train,y_train)
y_pred=lo.predict(x_test)

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[8638, 2759],
#        [   0,    0]], dtype=int64)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.75791875054839
